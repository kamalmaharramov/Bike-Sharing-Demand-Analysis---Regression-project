# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data_original=pd.read_csv("hour.csv")
data_original.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
data_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
data_original.rename(columns={'weathersit':'weather',
                       'yr':'year',
                       'mnth':'month',
                       'hr':'hour',
                       'hum':'humidity',
                       'cnt':'count'},inplace=True)

# %%
data_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   year        17379 non-null  int64
#  4   month       17379 non-null  int64
#  5   hour        17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weather     17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  humidity    17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  count       17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
data_original.columns
# Out:
# Index(['instant', 'dteday', 'season', 'year', 'month', 'hour', 'holiday',
#        'weekday', 'workingday', 'weather', 'temp', 'atemp', 'humidity',
#        'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
data_original.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# year          0
# month         0
# hour          0
# holiday       0
# weekday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.pointplot(data=data_original, x='hour', y='count', hue='weather', ax=ax)
ax.set(title='Count of bikes during different weathers')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during different weathers')]

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.pointplot(data=data_original, x='hour', y='count', hue='weekday', ax=ax)
ax.set(title='Count of bikes during weekdays and weekends')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during weekdays and weekends')]

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.pointplot(data=data_original, x='hour', y='casual', hue='weekday', ax=ax)
ax.set(title='Count of bikes during weekdays and weekends: Unregistered users')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during weekdays and weekends: Unregistered users')]

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.pointplot(data=data_original, x='hour', y='registered', hue='weekday', ax=ax)
ax.set(title='Count of bikes during weekdays and weekends: Registered users')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during weekdays and weekends: Registered users')]

# %%
corr=data_original.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13888\157996709.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data_original.corr()

# %%
corr["count"]
# Out:
# instant       0.278379
# season        0.178056
# year          0.250495
# month         0.120638
# hour          0.394071
# holiday      -0.030927
# weekday       0.026900
# workingday    0.030284
# weather      -0.142426
# temp          0.404772
# atemp         0.400929
# humidity     -0.322911
# windspeed     0.093234
# casual        0.694564
# registered    0.972151
# count         1.000000
# Name: count, dtype: float64

# %%
data_original["season"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 17374    1
# 17375    1
# 17376    1
# 17377    1
# 17378    1
# Name: season, Length: 17379, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
corr_columns=corr[((corr["count"]>0.2)|(corr["count"]<-0.2))&(corr["count"]!=1)]["count"].index.tolist()

# %%
corr_columns
# Out:
# ['instant',
#  'year',
#  'hour',
#  'temp',
#  'atemp',
#  'humidity',
#  'casual',
#  'registered']

# %%
x=data_original[corr_columns]

# %%
y=data_original["count"]

# %%
lecoder=OneHotEncoder()

# %%
x=pd.get_dummies(x)

# %%
x
# Out:
#        instant  year  hour  temp   atemp  humidity  casual  registered
# 0            1     0     0  0.24  0.2879      0.81       3          13
# 1            2     0     1  0.22  0.2727      0.80       8          32
# 2            3     0     2  0.22  0.2727      0.80       5          27
# 3            4     0     3  0.24  0.2879      0.75       3          10
# 4            5     0     4  0.24  0.2879      0.75       0           1
# ...        ...   ...   ...   ...     ...       ...     ...         ...
# 17374    17375     1    19  0.26  0.2576      0.60      11         108
# 17375    17376     1    20  0.26  0.2576      0.60       8          81
# 17376    17377     1    21  0.26  0.2576      0.60       7          83
# 17377    17378     1    22  0.26  0.2727      0.56      13          48
# 17378    17379     1    23  0.26  0.2727      0.65      12          37
#
# [17379 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression, Ridge,Lasso

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor

# %%
models = [LinearRegression(), Ridge(),DecisionTreeRegressor(), RandomForestRegressor(),ExtraTreesRegressor(),
          GradientBoostingRegressor()]
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,mean_squared_log_error,median_absolute_error

# %%
for model in models:
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    print(f"{model}")
    print("r2 score:",r2_score(y_test,pred))
    print("mean_absolute_error:",mean_absolute_error(y_test,pred))
    print("mean_squared_error:",mean_squared_error(y_test,pred))
    print("mean_squared_log_error:",mean_squared_log_error(y_test,pred))
    print("median_absolute_error:",median_absolute_error(y_test,pred))
# Out:
# LinearRegression()
# r2 score: 1.0
# mean_absolute_error: 2.4652317522734442e-11
# mean_squared_error: 8.161407396040936e-22
# mean_squared_log_error: 6.383943736971624e-24
# median_absolute_error: 2.440003754600184e-11
# Ridge()
# r2 score: 0.9999999999999999
# mean_absolute_error: 1.1025753553645976e-06
# mean_squared_error: 2.9577599535779407e-12
# mean_squared_log_error: 4.859602219666402e-15
# median_absolute_error: 7.518125411110077e-07
# DecisionTreeRegressor()
# r2 score: 0.9992746366197388
# mean_absolute_error: 2.0678941311852705
# mean_squared_error: 22.96892980437284
# mean_squared_log_error: 0.0003022037318124241
# median_absolute_error: 1.0
# RandomForestRegressor()
# r2 score: 0.9997787477356876
# mean_absolute_error: 0.8957594936708861
# mean_squared_error: 7.006043958573072
# mean_squared_log_error: 7.074221391581057e-05
# median_absolute_error: 0.3100000000000023
# ExtraTreesRegressor()
# r2 score: 0.9998793905582704
# mean_absolute_error: 0.5784349827387805
# ...
